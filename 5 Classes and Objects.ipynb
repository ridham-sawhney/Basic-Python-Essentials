# %%
class Dog:
    def __init__(self,name):
        self.name = name
        self.legs = 4
    
    def speak(self):
        print(self.name + " says : Bhow")

# %%
my_dog = Dog("Romeo")

# %%
my_dog.speak()
# Out:
# Romeo says : Bhow
