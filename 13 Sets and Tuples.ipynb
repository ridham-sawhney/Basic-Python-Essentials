# %% [markdown]
# Sets

# %%
mySet = {'a','b','c'}
print(mySet)
# Out:
# {'b', 'c', 'a'}

# %%
mySet = set(['a','b','c'])
print(mySet)
# Out:
# {'b', 'c', 'a'}

# %%
mySet = set(('a','b','c'))
print(mySet)
# Out:
# {'b', 'c', 'a'}

# %%
# Remove duplicates from the list
myList = ['a','b','c','b','a']
print(list(set(myList)))
# Out:
# ['b', 'c', 'a']

# %%
'a' in mySet
# Out:
# True

# %%
'bsa' in mySet
# Out:
# False

# %%
mySet = {'a','b','c'}
mySet.add('d')
print(mySet)
mySet.pop()
print(mySet)
mySet.discard('d') #discard doesnot throw error if element is not there in the set
print(mySet)
# Out:
# {'b', 'c', 'd', 'a'}
# {'c', 'd', 'a'}
# {'c', 'a'}

# %% [markdown]
# Tuples

# %%
myTuple=('a','b','c')
print(myTuple)
# Out:
# ('a', 'b', 'c')

# %%
myTuple[0]
# Out:
# 'a'

# %%
def getTuple():
    return 1,2,3

# %%
type(getTuple())
# Out:
# tuple

# %%
a,b,c = getTuple()
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3
