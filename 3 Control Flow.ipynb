# %%
a = True
if a:
    print("I am True so running")
print("I will run anyway")
# Out:
# I am True so running
# I will run anyway

# %%
a = False
if a:
    print("I am True so running")
print("I will run anyway")
# Out:
# I will run anyway

# %% [markdown]
# Loops

# %%
a = [1,2,3,4,5]

for item  in a:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while(i<5):
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
