# %%
from math import pi

# %%
sentence = "My name is Ridham Sawhney."

# %%
print(sentence[0])
# Out:
# M

# %%
print(sentence[0:7])
# Out:
# My name

# %%
print(sentence[:9])
# Out:
# My name i

# %%
print(sentence[9:])
# Out:
# s Ridham Sawhney.

# %%
my_list = [1,2,3,4,5,6]

# %%
print(my_list[3:])
# Out:
# [4, 5, 6]

# %%
f'Sum of 1 and 2 is {1+2}'
# Out:
# 'Sum of 1 and 2 is 3'

# %%
f'Pi is {pi}'
# Out:
# 'Pi is 3.141592653589793'

# %%
'My {} is {}'.format('name','Ridham')
# Out:
# 'My name is Ridham'

# %%
multi_line_string = '''
Hi My name is \'\'\' Ridham sawhney
I am a software developer
'''

# %%
multi_line_string
# Out:
# "\nHi My name is ''' Ridham sawhney\nI am a software developer\n"
