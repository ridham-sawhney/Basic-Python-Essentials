# %%
animalList = [('c','cat'),('d','dog'),('e','elephant')]
animalList
# Out:
# [('c', 'cat'), ('d', 'dog'), ('e', 'elephant')]

# %%
animals = {animal[0]:animal[1] for animal in animalList}
animals
# Out:
# {'c': 'cat', 'd': 'dog', 'e': 'elephant'}

# %%
animals = {key:value for key,value in animalList}
animals
# what happening is a,b = (1,2)  a=2 , b=2
# Out:
# {'c': 'cat', 'd': 'dog', 'e': 'elephant'}

# %%
animals.keys()
# Out:
# dict_keys(['c', 'd', 'e'])

# %%
animals.values()
# Out:
# dict_values(['cat', 'dog', 'elephant'])

# %%
animals.items()
# Out:
# dict_items([('c', 'cat'), ('d', 'dog'), ('e', 'elephant')])

# %%
[{'letter':key,'value':value} for key,value in animals.items()]
# Out:
# [{'letter': 'c', 'value': 'cat'},
#  {'letter': 'd', 'value': 'dog'},
#  {'letter': 'e', 'value': 'elephant'}]
