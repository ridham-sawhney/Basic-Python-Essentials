# %%
animals = {
    'a':'aardvak',
    'd':'dog',
    'c':'cat'
}
animals
# Out:
# {'a': 'aardvak', 'd': 'dog', 'c': 'cat'}

# %%
animals['a']
# Out:
# 'aardvak'

# %%
animals['e'] = 'elephant'
animals
# Out:
# {'a': 'aardvak', 'd': 'dog', 'c': 'cat', 'e': 'elephant'}

# %%
animals.keys()
# Out:
# dict_keys(['a', 'd', 'c', 'e'])

# %%
animals.values()
# Out:
# dict_values(['aardvak', 'dog', 'cat', 'elephant'])

# %%
list(animals.keys())
# Out:
# ['a', 'd', 'c', 'e']

# %%
animals['f']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 animals['f']
#
# KeyError: 'f'

# %%
print(animals.get('f'))
print(animals.get('e'))
# Out:
# None
# elephant

# %%
len(animals)
# Out:
# 4

# %%
animals = {
    'a':['antelope','aardvik'],
    'b':['bear']
}
print(animals)
animals['c']='cat'
print(animals)
if 'd' not in animals:
    animals['d']=[]
animals['d'].append('dog')
print(animals)
# Out:
# {'a': ['antelope', 'aardvik'], 'b': ['bear']}
# {'a': ['antelope', 'aardvik'], 'b': ['bear'], 'c': 'cat'}
# {'a': ['antelope', 'aardvik'], 'b': ['bear'], 'c': 'cat', 'd': ['dog']}

# %% [markdown]
# Default Dict

# %%
from collections import defaultdict

# %%
animals = defaultdict(list)
print(animals)

animals['e'].append('elephant')
animals['e'].append('emu')
print(animals)
# Out:
# defaultdict(<class 'list'>, {})
# defaultdict(<class 'list'>, {'e': ['elephant', 'emu']})
