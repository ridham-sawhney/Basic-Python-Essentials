# %%
print("Bytes")
# Out:
# Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smily = bytes('🙂','utf-8')
smily
# Out:
# b'\xf0\x9f\x99\x82'

# %%
smily.decode('utf-8')
# Out:
# '🙂'

# %%
smilyBites = bytearray('🙂','utf-8')

# %%
smilyBites
# Out:
# bytearray(b'\xf0\x9f\x99\x82')

# %%
smilyBites[3] = int('88',16)

# %%
smilyBites.decode("utf-8")
# Out:
# '🙈'
