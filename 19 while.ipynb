# %%
from datetime import datetime

# %%
datetime.now().second
# Out:
# 8

# %%
wait_until = 14
while datetime.now().second != wait_until:
    pass
print("We are at the 14th second")
# Out:
# We are at the 14th second
