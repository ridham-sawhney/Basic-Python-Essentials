# %%
my_list = [1,2,3,4,5]

# %%
print(my_list)
print(f"Length of my list is {len(my_list)}")
# Out:
# [1, 2, 3, 4, 5]
# Length of my list is 5

# %%
my_list = [1,2,3,4,5,[1,2],["String1"],[True,False]]

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, [1, 2], ['String1'], [True, False]]

# %%
my_set = {1,1,1,1,1,1,2,3,4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
[1,2] == [2,1]
# Out:
# False

# %%
{1,2} == {2,1}
# Out:
# True

# %% [markdown]
# Tuples

# %%
my_tuples = (1,2,3)
# Cannot append or add in tuples

# %%
print(my_tuples)
# Out:
# (1, 2, 3)

# %% [markdown]
# Dictionaries

# %%
my_dict = {
    'apple':'A red fruit',
    'mango':'A yellow fruit',
}

# %%
my_dict['apple']
# Out:
# 'A red fruit'

# %%
my_dict.get("apple")
# Out:
# 'A red fruit'

# %%
print(my_dict.get("def") == None)
# Out:
# True

# %% [markdown]
# MEmbership

# %%
1 in [1,2,3,4]
# Out:
# True

# %%
'act' in 'I am an actor'
# Out:
# True

# %%
'act' not in 'I am a hero'
# Out:
# True
